# %% [markdown]
# ## Importando as bibliotecas

# %%
# boas práticas: criar uma célula com todas as bibliotecas necessárias
# importando as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Analisando o grupo http://dados.ufrn.br/group/ensino

# %%
# Turmas 2014.1, 2014.2, 2015.1, 2015.2, 2016.1, 2016.2, 2017.1, 2017.2
# http://dados.ufrn.br/dataset/turmas

# turmas
turmas_url = [
    'http://bit.do/turmas_ufrn_2014_1',
    'http://bit.do/turmas_ufrn_2014_2',
    'http://bit.do/turmas_ufrn_2015_1',
    'http://bit.do/turmas_ufrn_2015_2',
    'http://bit.do/turmas_ufrn_2016_1',
    'http://bit.do/turmas_ufrn_2016_2',
    'http://bit.do/turmas_ufrn_2017_1',
    'http://bit.do/turmas_ufrn_2017_2'
]

# matrículas em componentes
notas_url = [
    'http://bit.do/notas_ufrn_2014_1',
    'http://bit.do/notas_ufrn_2014_2',
    'http://bit.do/notas_ufrn_2015_1',
    'http://bit.do/notas_ufrn_2015_2',
    'http://bit.do/notas_ufrn_2016_1',
    'http://bit.do/notas_ufrn_2016_2',
    'http://bit.do/notas_ufrn_2017_1',
    'http://bit.do/notas_ufrn_2017_2'
]

# componentes curriculares presenciais
disciplinas_url = 'http://bit.do/componentes_curriculares_ufrn'

# docentes da ufrn atualizado em 2018
#docentes_url = 'http://bit.do/docentes_ufrn_2018'

# turmas
turmas = []
for i in range(len(turmas_url)):
    turmas.insert(i, pd.read_csv(turmas_url[i], sep=';'))

# matriculas em componentes
notas = []
for i in range(len(notas_url)):
    notas.insert(i, pd.read_csv(notas_url[i], sep=';'))

# componentes curriculares presenciais
# por alguma razão ou outra, esse dataset tinha algum lixo em linhas que ocasionava 
# erros de leitura, dessa forma foi realizado um filtro apenas por colunas mais importantes
df_disciplinas = pd.read_csv(disciplinas_url, 
                          sep=';', 
                          usecols=["id_componente","codigo","nivel","nome","unidade_responsavel"])

#docentes = pd.read_csv(docentes_url, sep=';')

# %%
df_turmas = pd.concat(turmas)
df_notas = pd.concat(notas)

# concatenando todas as listas em um dataframe
df_turmas = pd.concat(turmas)
df_notas = pd.concat(notas)

# limpandos os index após o merge
df_turmas.reset_index(drop=True,inplace=True)
df_notas.reset_index(drop=True,inplace=True)

# %%
auxilioDisciplinas = df_disciplinas
auxilioTurmas = df_turmas
auxilioNotas = df_notas

# %%
df_turmas.tail()
# Out:
#         id_turma codigo_turma id_docente_interno  id_docente_externo  \
# 115372  57620200           01        5.75266e+06                 NaN
# 115373  57620243           01        5.75309e+06                 NaN
# 115374  57620655           02        5.75309e+06                 NaN
# 115375  57621958           02        5.75309e+06                 NaN
# 115376  57622680           05                NaN         129053338.0
#
#        observacao  id_componente_curricular   nivel_ensino campus_turma  \
# 115372        NaN                   39732.0  STRICTO SENSU          NaN
# 115373        NaN                   65612.0     LATO SENSU          NaN
# 115374        NaN                   65612.0     LATO SENSU          NaN
# 115375        NaN                   62216.0     LATO SENSU          NaN
# 115376        NaN                   65507.0        TÉCNICO          NaN
#
#                                   local   ano     ...         tipo distancia  \
# 115372           Auditório do Química 3  2017     ...      REGULAR         f
# 115373  Campus da UFRN em Currais Novos  2017     ...      REGULAR         f
# 115374                            CCHLA  2017     ...      REGULAR         f
# 115375                   Campus da UFRN  2017     ...      REGULAR         f
# 115376            SENADOR ELOI DE SOUZA  2017     ...      REGULAR         f
#
#               data_consolidacao agrupadora id_turma_agrupadora  \
# 115372  2018-04-08 15:15:49.821          f                 NaN
# 115373  2018-02-16 13:09:34.719          f                 NaN
# 115374                      NaN          f                 NaN
# 115375  2018-02-10 15:49:39.029          f                 NaN
# 115376                      NaN          f                 NaN
#
#        qtd_aulas_lancadas situacao_turma convenio modalidade_participantes  \
# 115372               80.0    CONSOLIDADA      NaN               Presencial
# 115373               20.0    CONSOLIDADA      NaN               Presencial
# 115374                NaN         ABERTA      NaN               Presencial
# 115375                0.0    CONSOLIDADA      NaN               Presencial
# 115376                NaN         ABERTA      NaN               Presencial
#
#        Unnamed: 25
# 115372         NaN
# 115373         NaN
# 115374         NaN
# 115375         NaN
# 115376         NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Preparação e Limpeza dos Dados

# %%
df_disciplinas
# Out:
#                                            id_componente   codigo nivel  \
# 0                                                  18643   MUT508     T
# 1                                                  18644   MUT516     T
# 2                                                  18645   MUT520     T
# 3                                                  18646   MUT165     T
# 4                                                  18647   MUT167     T
# 5                                                  18648   MUT169     T
# 6                                                  18649   MUT526     T
# 7                                                  18650   MUT506     T
# 8                                                  18651   MUT101     T
# 9                                                  18652   MUT102     T
# 10                                                 18653   MUT103     T
# 11                                                 18654   MUT104     T
# 12                                                 18655   MUT105     T
# 13                                                 18656   MUT106     T
# 14                                                 18657   MUT107     T
# 15                                                 18658   MUT108     T
# 16                                                 18659   MUT109     T
# 17                                                 18660   MUT110     T
# 18                                                 18661   MUT111     T
# 19                                                 18662   MUT112     T
# 20                                                 18663   MUT113     T
# 21                                                 18664   MUT114     T
# 22                                                 18665   MUT115     T
# 23                                                 18666   MUT116     T
# 24                                                 18667   MUT117     T
# 25                                                 18668   MUT118     T
# 26                                                 18669   MUT119     T
# 27                                                 18670   MUT120     T
# 28                                                 18671   MUT121     T
# 29                                                 18672   MUT122     T
# ...                                                  ...      ...   ...
# 39085  GARCEZ, José Maria Rossani. A Arbitragem na Er...      NaN   NaN
# 39086  GARCIA JUNIOR, Armando Alvarez. Foro Competent...      NaN   NaN
# 39087  LEE, João Bosco. Arbitragem Comercial Internac...      NaN   NaN
# 39088  MACHADO GRANZIERA, Maria Luiza. Contratos Inte...      NaN   NaN
# 39089  MELO, Jairo Silva. Contratos Internacionais e ...      NaN   NaN
# 39090  RECHSTEINER, Beat Walter, Arbitragem Privada I...      NaN   NaN
# 39091  _____________. Direito Internacional Privado. ...      NaN   NaN
# 39092  RODAS, João Grandino. Contratos Internacionais...      NaN   NaN
# 39093  STRENGER, Irineu. Contratos internacionais do ...      NaN   NaN
# 39094  ________________. Direito Internacional Privad...      NaN   NaN
# 39095  VALLADÃO, Haroldo. Direito Internacional Priva...     2010     2
# 39096                                            2056261  LAT1146     L
# 39097                                            2056262  LAT1147     L
# 39098                                            2056263  LAT1148     L
# 39099                                            2056264  LAT1149     L
# 39100                                            2056265  LAT1150     L
# 39101                                          104695451  NEI0020     I
# 39102                                          104695453  NEI0021     I
# 39103                                          108276069  NEI0011     U
# 39104                                          108276070  NEI0012     U
# 39105                                          108276071  NEI0013     U
# 39106                                          108276072  NEI0015     U
# 39107                                          108276073  NEI0017     U
# 39108                                          108276074  NEI0014     U
# 39109                                          108276075  NEI0016     U
# 39110                                          108276076  NEI0018     U
# 39111                                          108276085  NEI0050     U
# 39112                                          108276087  NEI0051     U
# 39113                                          108276089  NEI0052     U
# 27                         ESCOLA DE MÚSICA
# 28                         ESCOLA DE MÚSICA
# 29                         ESCOLA DE MÚSICA
# ...                                     ...
# 39085                                   NaN
# 39086                                   NaN
# 39087                                   NaN
# 39088                                   NaN
# 39089                                   NaN
# 39090                                   NaN
# 39091                                   NaN
# 39092                                   NaN
# 39093                                   NaN
# 39094                                   NaN
# 39095                                   NaN
# 39096  PROGRAMA DE PÓS-GRADUAÇÃO EM DIREITO
# 39097  PROGRAMA DE PÓS-GRADUAÇÃO EM DIREITO
# 39098  PROGRAMA DE PÓS-GRADUAÇÃO EM DIREITO
# 39099  PROGRAMA DE PÓS-GRADUAÇÃO EM DIREITO
# 39100  PROGRAMA DE PÓS-GRADUAÇÃO EM DIREITO
# 39101        NÚCLEO DE EDUCAÇÃO DA INFÂNCIA
# 39102        NÚCLEO DE EDUCAÇÃO DA INFÂNCIA
# 39103        NÚCLEO DE EDUCAÇÃO DA INFÂNCIA
# 39104        NÚCLEO DE EDUCAÇÃO DA INFÂNCIA
# 39105        NÚCLEO DE EDUCAÇÃO DA INFÂNCIA
# 39106        NÚCLEO DE EDUCAÇÃO DA INFÂNCIA
# 39107        NÚCLEO DE EDUCAÇÃO DA INFÂNCIA
# 39108        NÚCLEO DE EDUCAÇÃO DA INFÂNCIA
# 39109        NÚCLEO DE EDUCAÇÃO DA INFÂNCIA
# 39110        NÚCLEO DE EDUCAÇÃO DA INFÂNCIA
# 39111        NÚCLEO DE EDUCAÇÃO DA INFÂNCIA
# 39112        NÚCLEO DE EDUCAÇÃO DA INFÂNCIA
# 39113        NÚCLEO DE EDUCAÇÃO DA INFÂNCIA
# 39114        NÚCLEO DE EDUCAÇÃO DA INFÂNCIA
#
# [39115 rows x 5 columns]

# %%
# Adaptando o dataframe turma e disciplinas para o merge
# Esse procedimento é necessário pois o dataframe turma está codificado com ids

# A coluna id_componente precisa ser a mesma em ambos os dataframes
df_turmas.rename(columns={'id_componente_curricular': 'id_componente'}, inplace=True)

# id_componente em ambos os dataframes precisam ser do mesmo tipo
df_turmas.id_componente = df_turmas.id_componente.astype(str)
df_disciplinas = df_disciplinas.id_componente.astype(str)

# Limpando o dataframe disciplinas com linhas desnecessárias
df_disciplinas.dropna(inplace=True)
df_disciplinas = df_disciplinas[~df_disciplinas.id_componente.duplicated()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-0ef48fe4aad8> in <module>()
#       7 # id_componente em ambos os dataframes precisam ser do mesmo tipo
#       8 df_turmas.id_componente = df_turmas.id_componente.astype(str)
# ----> 9 df_disciplinas = df_disciplinas.id_componente.astype(str)
#      10
#      11 # Limpando o dataframe disciplinas com linhas desnecessárias
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'id_componente'

# %%
# Fazendo um merge entre o dataframe turmas e disciplinas utilizando como base a coluna id_componente
# https://pandas.pydata.org/pandas-docs/stable/merging.html
colunas = ["id_turma","id_docente_interno","codigo","nivel_ensino","nome","unidade_responsavel",
          "situacao_turma","capacidade_aluno","descricao_horario"]

# merge os dois dataframes utilizando como base a coluna id_componente
merge_turmas_disciplinas = pd.merge(df_turmas, df_disciplinas, on='id_componente')[colunas]

#merge_turmas_disciplinas.dropna(inplace=True)
merge_turmas_disciplinas.head()
# Out:
# Empty DataFrame
# Columns: [id_turma, id_docente_interno, codigo, nivel_ensino, nome, unidade_responsavel, situacao_turma, capacidade_aluno, descricao_horario]
# Index: []

# %% [markdown]
# ## Filtrar as turmas do IMD
