# %% [markdown]
# ## Importando as bibliotecas

# %%
# boas práticas: criar uma célula com todas as bibliotecas necessárias
# importando as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
debug = True

# %% [markdown]
# ## Analisando o grupo http://dados.ufrn.br/group/ensino

# %%
# Turmas 2014.1, 2014.2, 2015.1, 2015.2, 2016.1, 2016.2, 2017.1, 2017.2
# http://dados.ufrn.br/dataset/turmas
# URLs utiliazadas

# turmas
turmas_url = [
    'http://bit.do/turmas_ufrn_2014_1',
    'http://bit.do/turmas_ufrn_2014_2',
    'http://bit.do/turmas_ufrn_2015_1',
    'http://bit.do/turmas_ufrn_2015_2',
    'http://bit.do/turmas_ufrn_2016_1',
    'http://bit.do/turmas_ufrn_2016_2',
    'http://bit.do/turmas_ufrn_2017_1',
    'http://bit.do/turmas_ufrn_2017_2'
]

# matrículas em componentes
notas_url = [
    'http://bit.do/notas_ufrn_2014_1',
    'http://bit.do/notas_ufrn_2014_2',
    'http://bit.do/notas_ufrn_2015_1',
    'http://bit.do/notas_ufrn_2015_2',
    'http://bit.do/notas_ufrn_2016_1',
    'http://bit.do/notas_ufrn_2016_2',
    'http://bit.do/notas_ufrn_2017_1',
    'http://bit.do/notas_ufrn_2017_2'
]

# componentes curriculares presenciais
disciplinas_url = 'http://bit.do/componentes_curriculares_ufrn'

if debug:
    turmas_url = ['turmas/' + i.replace('http://bit.do/', '') + '.csv' for i in turmas_url]
    notas_url = ['notas/' + i.replace('http://bit.do/', '') + '.csv' for i in notas_url]
    disciplinas_url = disciplinas_url.replace('http://bit.do/', '') + '.csv'

# %%
# turmas
semestres = ['2014.1', '2014.2', '2015.1', '2015.2', '2016.1', '2016.2', '2017.1', '2017.2']
turmas = []
for i in range(len(turmas_url)):
    turmas.insert(i, pd.read_csv(turmas_url[i], sep=';'))
    turmas[i]['semestre'] = semestres[i]

# matriculas em componentes
notas = []
for i in range(len(notas_url)):
    notas.insert(i, pd.read_csv(notas_url[i], sep=';'))

# componentes curriculares presenciais
# por alguma razão ou outra, esse dataset tinha algum lixo em linhas que ocasionava 
# erros de leitura, dessa forma foi realizado um filtro apenas por colunas mais importantes
df_disciplinas = pd.read_csv(disciplinas_url, sep=';', usecols=["id_componente","codigo","nivel","nome","unidade_responsavel"])

# %%
# concatenando todas as listas em um dataframe
df_turmas = pd.concat(turmas)
df_notas = pd.concat(notas)

# limpandos os index após o merge
df_turmas.reset_index(drop=True,inplace=True)
df_notas.reset_index(drop=True,inplace=True)

# %% [markdown]
# ## Preparação e Limpeza dos Dados

# %%
# Adaptando o dataframe turma e disciplinas para o merge
# Esse procedimento é necessário pois o dataframe turma está codificado com ids

# A coluna id_componente precisa ser a mesma em ambos os dataframes
df_turmas.rename(columns={'id_componente_curricular': 'id_componente'}, inplace=True)

# id_componente em ambos os dataframes precisam ser do mesmo tipo
df_turmas.id_componente = df_turmas.id_componente.astype(str)
df_turmas.id_componente = [i.replace('.0', '') for i in df_turmas.id_componente]

# # Limpando o dataframe disciplinas com linhas desnecessárias
df_disciplinas.dropna(inplace=True)
df_disciplinas = df_disciplinas[~df_disciplinas.id_componente.duplicated()]

# %%
# Fazendo um merge entre o dataframe turmas e disciplinas utilizando como base a coluna id_componente
# https://pandas.pydata.org/pandas-docs/stable/merging.html
colunas = ["id_turma","id_docente_interno","codigo","nivel_ensino","nome","unidade_responsavel",
          "situacao_turma","capacidade_aluno","descricao_horario", "semestre"]

# merge os dois dataframes utilizando como base a coluna id_componente
merge_turmas_disciplinas = pd.merge(df_turmas, df_disciplinas, on='id_componente')[colunas]

merge_turmas_disciplinas.dropna(inplace=True)
merge_turmas_disciplinas.head()
# Out:
#    id_turma id_docente_interno   codigo nivel_ensino  \
# 0   1205342        5.75255e+06  DCA0004   LATO SENSU
# 1   1205342              21790  DCA0004   LATO SENSU
# 2  57572417         5.7537e+06  DCA0004   LATO SENSU
# 3  57572417        5.75255e+06  DCA0004   LATO SENSU
# 4  57572417              21790  DCA0004   LATO SENSU
#
#                                          nome  \
# 0  CONTROLE AVANÇADO DE PROCESSOS INDUSTRIAIS
# 1  CONTROLE AVANÇADO DE PROCESSOS INDUSTRIAIS
# 2  CONTROLE AVANÇADO DE PROCESSOS INDUSTRIAIS
# 3  CONTROLE AVANÇADO DE PROCESSOS INDUSTRIAIS
# 4  CONTROLE AVANÇADO DE PROCESSOS INDUSTRIAIS
#
#                                  unidade_responsavel situacao_turma  \
# 0  DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...    CONSOLIDADA
# 1  DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...    CONSOLIDADA
# 2  DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...    CONSOLIDADA
# 3  DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...    CONSOLIDADA
# 4  DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...    CONSOLIDADA
#
#   capacidade_aluno                                 descricao_horario semestre
# 0               30  7M2345  7T3456  6N1234 (31/01/2014 - 27/03/2014)   2014.1
# 1               30  7M2345  7T3456  6N1234 (31/01/2014 - 27/03/2014)   2014.1
# 2               30                            7M12345  7T23456  7N12   2015.2
# 3               30                            7M12345  7T23456  7N12   2015.2
# 4               30                            7M12345  7T23456  7N12   2015.2

# %% [markdown]
# ## Filtrar as turmas do IMD

# %%
# filtrando as turmas com código IMD
turmas_imd = merge_turmas_disciplinas[merge_turmas_disciplinas.codigo.str.contains("IMD")]

# utilizar apenas disciplinas com código "CONSOLIDADA"
turmas_imd = turmas_imd[turmas_imd.situacao_turma == 'CONSOLIDADA']

turmas_imd.capacidade_aluno = turmas_imd.capacidade_aluno.astype(np.int64)
turmas_imd.head()
# Out:
#      id_turma id_docente_interno   codigo nivel_ensino  \
# 5023  1217917        5.75622e+06  IMD0019    GRADUAÇÃO
# 5024  1217917        5.75639e+06  IMD0019    GRADUAÇÃO
# 5025  1217918        5.75619e+06  IMD0019    GRADUAÇÃO
# 5026  1217918        5.75639e+06  IMD0019    GRADUAÇÃO
# 5027  1217919        5.75639e+06  IMD0019    GRADUAÇÃO
#
#                                             nome          unidade_responsavel  \
# 5023  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI  INSTITUTO METROPOLE DIGITAL
# 5024  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI  INSTITUTO METROPOLE DIGITAL
# 5025  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI  INSTITUTO METROPOLE DIGITAL
# 5026  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI  INSTITUTO METROPOLE DIGITAL
# 5027  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI  INSTITUTO METROPOLE DIGITAL
#
#      situacao_turma  capacidade_aluno                   descricao_horario  \
# 5023    CONSOLIDADA                70  236M1234 (27/01/2014 - 14/06/2014)
# 5024    CONSOLIDADA                70  236M1234 (27/01/2014 - 14/06/2014)
# 5025    CONSOLIDADA                70  236M1234 (27/01/2014 - 14/06/2014)
# 5026    CONSOLIDADA                70  236M1234 (27/01/2014 - 14/06/2014)
# 5027    CONSOLIDADA                72  236N1234 (27/01/2014 - 14/06/2014)
#
#      semestre
# 5023   2014.1
# 5024   2014.1
# 5025   2014.1
# 5026   2014.1
# 5027   2014.1

# %% [markdown]
# ## Notas IMD

# %%
# filtrar apenas as turmas do IMD
notas_imd = df_notas[df_notas.id_turma.isin(turmas_imd.id_turma)]

# merge entre os dataframes notas_imd e turmas_imd_nomesprof utilizando como referencia id_turma
notas_imd_merge = pd.merge(notas_imd, turmas_imd, on='id_turma')
# remover alunos duplicados
notas_imd_merge = notas_imd_merge[~notas_imd_merge.duplicated(subset = ['discente', 'id_turma'])]
notas_imd_merge.head()
# Out:
#     Unnamed: 10 descricao                          discente  faltas_unidade  \
# 0           NaN  APROVADO  932dabed29addc40f1e9d1cf51160601             0.0
# 6           NaN  APROVADO  12af1e1a9c5f528b10c0caee2888e036             0.0
# 12          NaN  APROVADO  7e644bd32245fd9c74f036d43907a425             0.0
# 18          NaN  APROVADO  6695de39125968ba9471e52e5887c045             0.0
# 24          NaN  APROVADO  1efcdbf03e9fcdc6990ea987bc15defb             0.0
#
#       id_curso id_turma  media_final  nota  numero_total_faltas reposicao  \
# 0   94676386.0  1228059         10.0  10.0                  0.0         f
# 6   94676386.0  1228059          9.3  10.0                  2.0         f
# 12  94676386.0  1228059         10.0  10.0                  0.0         f
# 18  94676386.0  1228059         10.0  10.0                  0.0         f
# 24  94676386.0  1228059         10.0  10.0                  0.0         f
#
#     unidade id_docente_interno   codigo nivel_ensino  \
# 0       1.0        5.75226e+06  IMD0015   LATO SENSU
# 6       1.0        5.75226e+06  IMD0015   LATO SENSU
# 12      1.0        5.75226e+06  IMD0015   LATO SENSU
# 18      1.0        5.75226e+06  IMD0015   LATO SENSU
# 24      1.0        5.75226e+06  IMD0015   LATO SENSU
#
#                                    nome          unidade_responsavel  \
# 0   DESENVOLVIMENTO WEB NO LADO CLIENTE  INSTITUTO METROPOLE DIGITAL
# 6   DESENVOLVIMENTO WEB NO LADO CLIENTE  INSTITUTO METROPOLE DIGITAL
# 12  DESENVOLVIMENTO WEB NO LADO CLIENTE  INSTITUTO METROPOLE DIGITAL
# 18  DESENVOLVIMENTO WEB NO LADO CLIENTE  INSTITUTO METROPOLE DIGITAL
# 24  DESENVOLVIMENTO WEB NO LADO CLIENTE  INSTITUTO METROPOLE DIGITAL
#
#    situacao_turma  capacidade_aluno descricao_horario semestre
# 0     CONSOLIDADA                30     246M12 7M2345   2014.1
# 6     CONSOLIDADA                30     246M12 7M2345   2014.1
# 12    CONSOLIDADA                30     246M12 7M2345   2014.1
# 18    CONSOLIDADA                30     246M12 7M2345   2014.1
# 24    CONSOLIDADA                30     246M12 7M2345   2014.1

# %% [markdown]
# ## Gráficos

# %%
# Disciplinas
notas_imd_merge.nome.unique()
# Out:
# array(['DESENVOLVIMENTO WEB NO LADO CLIENTE',
#        'PRÁTICAS DE LEITURA EM INGLÊS',
#        'PRÁTICAS DE LEITURA E ESCRITA EM PORTUGUÊS I',
#        'PRÁTICAS DE LEITURA E ESCRITA EM INGLÊS',
#        'LABORATÓRIO DE PROGRAMAÇÃO II',
#        'MASHUPS - RECRIANDO SISTEMAS ATRAVÉS DA WEB 2.0', 'TI VERDE',
#        'REDES DE COMPUTADORES', 'PROBABILIDADE',
#        'FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO I',
#        'TECNOLOGIA DA INFORMAÇÃO E SOCIEDADE',
#        'RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI',
#        'AVALIAÇÃO DA INTERAÇÃO HUMANO-COMPUTADOR',
#        'CÁLCULO DIFERENCIAL E INTEGRAL I',
#        'FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO II',
#        'ESTRUTURAS DE DADOS BÁSICAS II',
#        'INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO',
#        'ESTRUTURA DE DADOS BÁSICAS I', 'LABORATÓRIO DE PROGRAMAÇÃO I',
#        'ORGANIZAÇÃO E ARQUITETURA DE COMPUTADORES',
#        'VETORES E GEOMETRIA ANALÍTICA',
#        'PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO',
#        'MÉTODOS EXPERIMENTAIS NA INDÚSTRIA DE SOFTWARE',
#        'CONCEITOS E APLICAÇÕES PARA COMPUTAÇÃO NA NUVEM',
#        'SISTEMAS OPERACIONAIS',
#        'TÉCNICAS LÚDICAS PARA ENGAJAMENTO DE USUÁRIOS',
#        'PROGRAMAÇÃO DE SERVIÇOS WEB',
#        'DESIGN DE SOFTWARE COM USABILIDADE E INOVAÇÃO',
#        'BD E MAPEAMENTO OBJETO-RELACIONAL', 'ARQUITETURA DE SOFTWARE',
#        'LINGUAGEM DE PROGRAMAÇÃO II',
#        'TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO I',
#        'DESENVOLVIMENTO PARA DISPOSITIVOS MÓVEIS I (ANDROID)',
#        'LINGUAGEM DE PROGRAMAÇÃO I', 'SISTEMAS DIGITAIS RECONFIGURÁVEIS',
#        'FUNDAMENTOS PEDAGÓGICOS PARA A INFORMÁTICA EDUCACIONAL II',
#        'TÉCNICAS DE PROTOTIPAÇÃO E MONTAGEM DE CIRCUITOS E SISTEMAS ELETRÔNICOS',
#        'TÓPICOS ESPECIAIS EM INFORMÁTICA EDUCACIONAL I',
#        'INTRODUÇÃO A ORGANIZAÇÃO E ARQUITETURA DE COMPUTADORES',
#        'BANCO DE DADOS', 'TECNOLOGIAS EDUCACIONAIS',
#        'PROJETOS BASEADOS EM MICROCONTROLADORES',
#        'TEORIA DE CIRCUITOS ELÉTRICOS',
#        'DESENVOLVIMENTO PARA DISPOSITIVOS MÓVEIS II (ANDROID AVANÇADO)',
#        'FUNDAMENTOS DE SISTEMAS DE INFORMAÇÃO', 'DESIGN DE SOFTWARE II',
#        'DESENVOLVIMENTO PARA DISPOSITIVOS MÓVEIS',
#        'DESENVOLVIMENTO DE SISTEMAS WEB I', 'DESIGN DE SOFTWARE I',
#        'LABORATÓRIO DE CIRCUITOS LÓGICOS',
#        'TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO II',
#        'DESIGN E USABILIDADE EM APLICAÇÕES MÓVEIS',
#        'INTRODUÇÃO A SISTEMAS OPERACIONAIS',
#        'RELAÇÕES ENTRE COMUNICAÇÃO, MÍDIA E EDUCAÇÃO',
#        'CIRCUITOS LÓGICOS', 'SERVIÇOS E COMPUTAÇÃO NA NUVEM',
#        'INTRODUÇÃO A COMPUTAÇÃO MÓVEL E UBÍQUA',
#        'JOGOS DIGITAIS COMO FERRAMENTA PEDAGÓGICA',
#        'METODOLOGIAS DE PROJETOS EM SISTEMAS EMBARCADOS',
#        'PRÁTICAS DE LEITURA E ESCRITA EM PORTUGUÊS II',
#        'PROCESSO DE DESENVOLVIMENTO DE SOFTWARE EDUCACIONAL',
#        'SISTEMAS COLABORATIVOS DE APOIO À APRENDIZAGEM',
#        'TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO V',
#        'DESENVOLVIMENTO DE SISTEMAS WEB II',
#        'INTRODUÇÃO À GOVERNANÇA E GESTÃO DE TI',
#        'INTRODUÇÃO A SISTEMAS DE CONTROLE', 'ACESSIBILIDADE DIGITAL',
#        'PROGRAMACAO ORIENTADA A OBJETOS', 'REDES MÓVEIS',
#        'PROGRAMAÇÃO CONCORRENTE E DISTRIBUÍDA',
#        'LEVANTAMENTO E MODELAGEM DE REQUISITOS',
#        'SISTEMAS DE INTELIGÊNCIA EMPRESARIAL', 'COMUNICAÇÃO SEM FIO',
#        'TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO IV',
#        'TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO III',
#        'FUNDAMENTOS PEDAGÓGICOS PARA A INFORMÁTICA EDUCACIONAL I',
#        'REDES DE COMUNICAÇÃO EM SISTEMAS EMBARCADOS',
#        'PROJETO INTEGRADO I', 'PROGRAMAÇÃO COM BANCO DE DADOS',
#        'PROTOCOLO E SERVIÇOS DE INTERNET',
#        'DESENVOLVIMENTO PARA DISPOSITIVOS MÓVEIS V (HTML5 E TECNOLOGIAS HÍBRIDAS)',
#        'JOGOS PARA DISPOSITIVOS MÓVEIS',
#        'DESENVOLVIMENTO PARA DISPOSITIVOS MÓVEIS III (WINDOWS PHONE)',
#        'DESENVOLVIMENTO PARA DISPOSITIVOS MÓVEIS IV (IOS)',
#        'CIRCUITOS ELETRÔNICOS', 'PROCESSAMENTO DIGITAL DE SINAIS',
#        'PRINCÍPIOS DE LEGISLAÇÃO APLICÁVEIS À TECNOLOGIA DA INFORMAÇÃO E COMUNICAÇÃO DE DADOS',
#        'GESTÃO DE INFRAESTRUTURA DE TI',
#        'TÓPICOS ESPECIAIS EM SISTEMAS EMBARCADOS A"',
#        'PROJETO INTEGRADO II', 'TÓPICOS ESPECIAIS EM BIOINFORMÁTICA A"',
#        'SEGURANÇA DA INFORMAÇÃO', 'DESIGN DA INTERAÇÃO HUMANO-COMPUTADOR',
#        'TÓPICOS AVANÇADOS EM COMPUTAÇÃO MÓVEL I', 'PROCESSOS DE SOFTWARE',
#        'SISTEMA DE INFORMAÇÃO DISTRIBUÍDO',
#        'ADMINISTRAÇÃO DE SISTEMAS OPERACIONAIS PARA REDES',
#        'TÓPICOS ESPECIAIS EM REDES DE COMPUTADORES A"',
#        'SISTEMAS EMBARCADOS DE TEMPO REAL',
#        'PROJETO DE INOVAÇÃO TECNOLÓGICA',
#        'TÓPICOS AVANÇADOS EM COMPUTAÇÃO MÓVEL II',
#        'INSTRUMENTAÇÃO ELETROELETRÔNICA', 'EMPREENDEDORISMO',
#        'INTRODUÇÃO AO TESTE DE SOFTWARE',
#        'TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO IX',
#        'DESENVOLVIMENTO PARA AMBIENTE DESKTOP',
#        'NUVENS COMPUTACIONAIS: INFRAESTRUTURA E SERVIÇOS PARA BIG DATA',
#        'SERVIÇOS DE REDE E TRANSPORTE', 'SEGURANÇA DE REDES',
#        'ADMINISTRAÇÃO DE SERVIÇOS DE REDES PARA INTERNET',
#        'APRENDIZAGEM BASEADA EM PROJETOS', 'EDUCAÇÃO A DISTÂNCIA',
#        'TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO VI',
#        'TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO XI',
#        'FUNDAMENTOS DE JOGOS DIGITAIS',
#        'APRENDIZAGEM DE MÁQUINA PARA BIG DATA',
#        'DESENVOLVIMENTO DE PROJETOS DE REDES DE COMPUTADORES',
#        'PROJETO INTEGRADOR DE REDES I',
#        'PROGRAMAÇÃO EM HARDWARE DE REDES',
#        'TÓPICOS ESPECIAIS EM REDES DE COMPUTADORES B"',
#        'TECNOLOGIAS DE COMUNICAÇÃO DE DADOS',
#        'PROGRAMAÇÃO CIENTÍFICA PARA BIG DATA',
#        'ANÁLISE ESTATÍSTICA PARA BIG DATA', 'MINERAÇÃO DE DADOS',
#        'TÓPICOS ESPECIAIS I',
#        'TÓPICOS ESPECIAIS EM INFORMÁTICA EDUCACIONAL B"',
#        'TÓPICOS ESPECIAIS EM INFORMÁTICA EDUCACIONAL C"',
#        'TÓPICOS ESPECIAIS EM INFORMÁTICA EDUCACIONAL D"',
#        'TÓPICOS ESPECIAIS EM SISTEMAS EMBARCADOS D"',
#        'TÓPICOS ESPECIAIS EM REDES DE COMPUTADORES C"',
#        'COMPUTAÇÃO DE ALTO-DESEMPENHO PARA BIG DATA',
#        'TÉCNICAS DE VISUALIZAÇÃO DE BIG DATA',
#        'INOVAÇÃO TECNOLÓGICA: PROCESSOS E AVALIAÇÃO DE IMPACTO',
#        'ESTUDOS DA ESTRUTURA DO PODER JUDICIÁRIO E SUAS TECNOLOGIAS',
#        'BUSINESS INTELLIGENCE E MINERAÇÃO DE DADOS', 'GESTÃO DE PROJETOS',
#        'GOVERNANÇA DE TI', 'APRENDIZADO BASEADO EM PROJETO 1',
#        'FERRAMENTAS PARA ANÁLISE DE SEQUÊNCIAS',
#        'TECNOLOGIAS EM LARGA ESCALA I', 'GERÊNCIA DE REDES',
#        'MECÂNICAS E BALANCEAMENTO DE JOGOS',
#        'TECNOLOGIA DA INFORMAÇÃO NA SAÚDE',
#        'ESTUDOS DA ESTRUTURA DO CONTROLE EXTERNO E SUAS TECNOLOGIAS'],
#       dtype=object)

# %% [markdown]
# ### Disciplinas do 1º Período
# Quantidade de estudantes aprovado com média igual ou superior a 7

# %%
# carregar a configuração padrão de cores do Seaborn
disciplinas_1 = [
    'RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI',
    'TECNOLOGIA DA INFORMAÇÃO E SOCIEDADE',
    'PRÁTICAS DE LEITURA E ESCRITA EM PORTUGUÊS I',
    'PRÁTICAS DE LEITURA E ESCRITA EM INGLÊS'
]
sns.set(font_scale=1.5)

# desenhar um gráfico de barras com a quantidade de estudantes aprovados em disciplinas do 1º período
# quantificados por semestre
for i, disciplina in enumerate(disciplinas_1):
    sns.factorplot("semestre", 
               data=notas_imd_merge[notas_imd_merge.descricao == 'APROVADO'][notas_imd_merge.nome == disciplina],
               kind="count", size=6, aspect=1.5)
    plt.title(disciplina)
    plt.xlabel('Semestre')
    plt.ylabel('Quantidade')

plt.show()
# Out:
# C:\Users\Carlos\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# ### Disciplinas do 2º Período
# Quantidade de estudantes aprovado com média igual ou superior a 7

# %%
# carregar a configuração padrão de cores do Seaborn
disciplinas_2 = [
    'CÁLCULO DIFERENCIAL E INTEGRAL I',
    'VETORES E GEOMETRIA ANALÍTICA',
    'PRÁTICAS DE LEITURA E ESCRITA EM PORTUGUÊS II',
    'FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO I',
    'INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO',
    'PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO'
]
sns.set(font_scale=1.5)

# desenhar um gráfico de barras com a quantidade de estudantes aprovados em disciplinas do 2º período
# quantificados por semestre
for i, disciplina in enumerate(disciplinas_2):
    sns.factorplot("semestre", 
               data=notas_imd_merge[notas_imd_merge.descricao == 'APROVADO'][notas_imd_merge.nome == disciplina],
               kind="count", size=6, aspect=1.5)
    plt.title(disciplina)
    plt.xlabel('Semestre')
    plt.ylabel('Quantidade')

plt.show()
# Out:
# C:\Users\Carlos\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()

# %% [markdown]
# ### Disciplinas do 3º Período
# Quantidade de estudantes aprovado com média igual ou superior a 7

# %%
# carregar a configuração padrão de cores do Seaborn
disciplinas_3 = [
    'LINGUAGEM DE PROGRAMAÇÃO I',
    'ESTRUTURA DE DADOS BÁSICAS I',
    'PROBABILIDADE',
    'FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO II'
]
sns.set(font_scale=1.5)

# desenhar um gráfico de barras com a quantidade de estudantes aprovados em disciplinas do 3º período
# quantificados por semestre
for i, disciplina in enumerate(disciplinas_3):
    sns.factorplot("semestre", 
               data=notas_imd_merge[notas_imd_merge.descricao == 'APROVADO'][notas_imd_merge.nome == disciplina],
               kind="count", size=6, aspect=1.5)
    plt.title(disciplina)
    plt.xlabel('Semestre')
    plt.ylabel('Quantidade')

plt.show()
# Out:
# C:\Users\Carlos\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
